# %%
import pandas as pd

# %% [markdown]
# #### indexing

# %%
df=pd.read_csv('world_population.csv' ,index_col='Country')
df.head()
# Out:
#                 Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan       36  AFG             Kabul      Asia       41128771.0
# Albania          138  ALB            Tirana    Europe        2842321.0
# Algeria           34  DZA           Algiers    Africa       44903225.0
# American Samoa   213  ASM         Pago Pago   Oceania          44273.0
# Andorra          203  AND  Andorra la Vella    Europe          79824.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan          38972230.0       33753499.0       28189672.0
# Albania               2866849.0        2882481.0        2913399.0
# Algeria              43451666.0       39543154.0       35856344.0
# American Samoa          46189.0          51368.0          54849.0
# Andorra                 77700.0          71746.0          71519.0
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.set_index('Country',inplace=True)

# %% [markdown]
# ### LOC , ILOC works with indexed data ,ILOC means integer location

# %%
df.loc['India']
# Out:
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# Continent                              Asia
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: India, dtype: object

# %%
df.reset_index(inplace=True)

# %% [markdown]
# #### setting multiple indexes

# %%
df.set_index(['Continent','Country'],inplace=True)

# %%
#df.reset_index(inplace=True)

# %%
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
df.sort_index()
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df.loc['Asia']
# Out:
#                       Rank CCA3              Capital  2022 Population  \
# Country
# Afghanistan             36  AFG                Kabul     4.112877e+07
# Armenia                140  ARM              Yerevan     2.780469e+06
# Azerbaijan              91  AZE                 Baku     1.035807e+07
# Bahrain                154  BHR               Manama     1.472233e+06
# Bangladesh               8  BGD                Dhaka     1.711864e+08
# Bhutan                 165  BTN              Thimphu     7.824550e+05
# Brunei                 175  BRN  Bandar Seri Begawan     4.490020e+05
# Cambodia                73  KHM           Phnom Penh     1.676784e+07
# China                    1  CHN              Beijing     1.425887e+09
# Georgia                131  GEO              Tbilisi     3.744385e+06
# Hong Kong              104  HKG            Hong Kong     7.488865e+06
# India                    2  IND            New Delhi     1.417173e+09
# ...

# %%
df.loc['Asia','India']
# Out:
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: (Asia, India), dtype: object

# %%
df.iloc[0] ## doesn't work as it is a multi index
# Out:
# Rank                                   36
# CCA3                                  AFG
# Capital                             Kabul
# 2022 Population                41128771.0
# 2020 Population                38972230.0
# 2015 Population                33753499.0
# 2010 Population                28189672.0
# 2000 Population                19542982.0
# 1990 Population                10694796.0
# 1980 Population                12486631.0
# 1970 Population                10752971.0
# Area (km²)                       652230.0
# Density (per km²)                 63.0587
# Growth Rate                        1.0257
# World Population Percentage          0.52
# Name: (Asia, Afghanistan), dtype: object

# %% [markdown]
# #### filter on columns

# %%
df=pd.read_csv('world_population.csv')
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df[df["Rank"]<10]
# Out:
#            Country  Rank CCA3           Capital      Continent  \
# 16      Bangladesh     8  BGD             Dhaka           Asia
# 27          Brazil     7  BRA          Brasilia  South America
# 41           China     1  CHN           Beijing           Asia
# 92           India     2  IND         New Delhi           Asia
# 93       Indonesia     4  IDN           Jakarta           Asia
# 149        Nigeria     6  NGA             Abuja         Africa
# 156       Pakistan     5  PAK         Islamabad           Asia
# 171         Russia     9  RUS            Moscow         Europe
# 221  United States     3  USA  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %%
df[df["Country"].str.contains("United")]
# Out:
#                           Country  Rank CCA3           Capital      Continent  \
# 219          United Arab Emirates    97  ARE         Abu Dhabi           Asia
# 220                United Kingdom    21  GBR            London         Europe
# 221                 United States     3  USA  Washington, D.C.  North America
# 222  United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df[df["Country"].str.contains("INDIA",case=False)]
# Out:
#    Country  Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# 92   India     2  IND  New Delhi      Asia     1.417173e+09     1.396387e+09
#
#     2015 Population  2010 Population  2000 Population  1990 Population  \
# 92     1.322867e+09     1.240614e+09     1.059634e+09              NaN
#
#     1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 92              NaN      557501301.0   3287590.0           431.0675
#
#     Growth Rate  World Population Percentage
# 92       1.0068                        17.77

# %%
df.filter(like='United',axis=0)
# Out:
#                                             Rank CCA3           Capital  \
# Continent     Country
# Asia          United Arab Emirates            97  ARE         Abu Dhabi
# Europe        United Kingdom                  21  GBR            London
# North America United States                    3  USA  Washington, D.C.
#               United States Virgin Islands   200  VIR  Charlotte Amalie
#
#                                             2022 Population  2020 Population  \
# Continent     Country
# Asia          United Arab Emirates                9441129.0        9287289.0
# Europe        United Kingdom                     67508936.0       67059474.0
# North America United States                     338289857.0      335942003.0
#               United States Virgin Islands          99465.0         100442.0
#
#                                             2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df[df['Rank']<10].sort_values('Rank')
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent     Country
# Asia          China             1  CHN           Beijing     1.425887e+09
#               India             2  IND         New Delhi     1.417173e+09
# North America United States     3  USA  Washington, D.C.     3.382899e+08
# Asia          Indonesia         4  IDN           Jakarta     2.755013e+08
#               Pakistan          5  PAK         Islamabad     2.358249e+08
# Africa        Nigeria           6  NGA             Abuja     2.185412e+08
# South America Brazil            7  BRA          Brasilia     2.153135e+08
# Asia          Bangladesh        8  BGD             Dhaka     1.711864e+08
# Europe        Russia            9  RUS            Moscow     1.447133e+08
#
#                              2020 Population  2015 Population  \
# Continent     Country
# Asia          China             1.424930e+09     1.393715e+09
# ...

# %%
## group by

# %%
df=pd.read_csv('Flavors.csv')

# %%
df.head()
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %%
df_grp_by=df.groupby('Base Flavor')

# %%
df_grp_by.mean()
# Out:
# C:\Users\WIN-10\AppData\Local\Temp\ipykernel_14264\3008920600.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grp_by.mean()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
data = {
    'Name': ['John', 'Matt', 'John', 'Cateline'],
    'math_Marks': [18, 20, 19, 15],
    'science_Marks': [10, 20, 15, 12]
}

# Create a DataFrame df
df = pd.DataFrame(data)

# %%
df["total"]=df["math_Marks"]+df["science_Marks"]

# %%
df
# Out:
#        Name  math_Marks  science_Marks  total
# 0      John          18             10     28
# 1      Matt          20             20     40
# 2      John          19             15     34
# 3  Cateline          15             12     27
